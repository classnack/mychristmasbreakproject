# %% [markdown]
# NAME: CLIFFORD AKUFFO NTOW
# INDEX NUMBER: 11348964
# CLASS: MTEN

# %%
# Importing pandas
import pandas as pd
# Importing matplotlib
import matplotlib as plt
# Importing numpy
import numpy as np

# %%
df = pd.read_csv('red_wine.csv')

# %%
#Previewing first 10 rows using head method
df.head(10)
#Previewing last 20 rows using tail method
df.tail(20)
#Using info method to check basic information on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
#Using describe method to obtain statistical information on the dataset
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
df.hist(figsize=(15,10), color = 'red')
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %%
df.plot(kind='scatter',x='alcohol', y='quality', c='red')
# Out:
# <Axes: xlabel='alcohol', ylabel='quality'>

# %% [markdown]
# FOR THE HISTOGRAM;
#
# Fixed acidity: This feature has a lower bound aroun4.5,nd an upper bound around  and a mean of 8.31.
#
# Volatile acidity: Similar to fixed acidity, this feathas a lower bound around 0.15 and an upper boundound aroud 1.5.
#
# Citric acid: The histogram indicates that the mean value of this feature is around 0.27.
#
# Residual sugar: This feature has a lower bound around 0.9 and an upper bound around 14.9.
#
# Chlorides: The histogram suggests that the mean value of this feature is around 0.09.
#
# Free sulfur dioxide: The histogram reveals that the mean value of the free sulphur dioxide is around 15.9.
#
# Total sulfur dioxide: The histogram shows that the mean value of the total sulphur dioxide is around 46.5.
#
# Density: The histogram indicates that the mean value of this feature is around 0.991.
#
# Ph: The histogram suggests that the mean value of this feature is around 3.04.
#
# Sulphates: The histogram reveals that the mean value of the sulphates is around 0.51.
#
# Alcohol: This feature has a lower bound around 8.5 and an uper bound around 14.9.
#
# Quality: The histogram suggests that the mean value of the quality is around 5.6
#
# FOR SCATTER PLOT;
# Each point on the scatter plot represents a different wine. The x-axis represents the alcohol percentage, while the y-axis represents the quality rating of the wine.
#
# In this scatter plot, you can observe how the points are grouped around different centroids. These centroids are the mean values of each cluster for the variables Alcohol and Qualty.
#
# For example, if two centroids are close together, it suggests that the clusters are similar with respect to the variables Alcohol and Qulity.
#
# On the other hand, if the centroids are far apart, it suggests that the clusters are disimilar.
#
# Thus, the scatter plot provides a visual understanding of the structure of the wine data and the relationships between the variables Alcohol an Quality.
#
# By examining the distribution of the points around the centroids, you can gain insights into the overall characteristics of each cluster.is feature is around 7.96.
